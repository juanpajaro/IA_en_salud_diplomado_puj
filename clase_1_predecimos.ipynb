# %% [markdown]
# <a href="https://colab.research.google.com/github/juanpajaro/IA_en_salud_diplomado_puj/blob/main/clase_1_predecimos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib

# %%
# Definir el nombre del archivo del modelo
model_filename = 'gradient_boosting_model.joblib'

# Cargar el modelo guardado
reg_loaded = joblib.load(model_filename)
print(f"Modelo '{model_filename}' cargado exitosamente.")

# %% [markdown]
# Resolver la siguiente celda

# %%
# Hacer una predicción con el modelo cargado usando los datos de prueba (X_test)
print("primer paciente")
print("datos: ", X_test[:1])
predictions = reg_loaded.predict(X_test)

print("\nPrimeras 5 predicciones:\n", predictions[:1])
print("\nForma de las predicciones:\n", predictions.shape)
