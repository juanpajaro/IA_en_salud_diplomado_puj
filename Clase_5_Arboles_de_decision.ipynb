# %% [markdown]
# <a href="https://colab.research.google.com/github/juanpajaro/IA_en_salud_diplomado_puj/blob/main/Clase_5_Arboles_de_decision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Gestión de datos:
# * Cargar los datos usando pandas.
# * Analisis grafico usando matplotlib.
# * Selección de vairables usando pandas.
# * División de los datos usando skitlearn.
#
# 2. Entrenamiento:
# * Seleccionar el modelo RandomForesClassifier.
# * Sintonizar el modelo usan GridSearchCV (n_estimators=100 criterion='gini', max_depth=None)
# * Entrenamiento fit
#
# 3. Evaluación:
# * Precision
# * Sensibilidad
# * F1-Score
# * Exactitud
